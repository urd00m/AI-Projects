# %%
import math

import numpy as np
import pandas as pd

import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# if this fails, open terminal (on Linux, Mac) or Anaconda Prompt (windows)
# and run:
# conda install -c huggingface transformers
from transformers import AutoModel, AutoTokenizer

# %%
tweets_df = pd.read_csv("data/tweets.csv")
tweets_df
# Out:
#           author                                            content country  \
# 0      katyperry  Is history repeating itself...?#DONTNORMALIZEH...     NaN
# 1      katyperry  @barackobama Thank you for your incredible gra...     NaN
# 2      katyperry                Life goals. https://t.co/XIn1qKMKQl     NaN
# 3      katyperry            Me right now 🙏🏻 https://t.co/gW55C1wrwd     NaN
# 4      katyperry  SISTERS ARE DOIN' IT FOR THEMSELVES! 🙌🏻💪🏻❤️ ht...     NaN
# ...          ...                                                ...     ...
# 52537   ddlovato               Life couldn't be better right now. 😊     NaN
# 52538   ddlovato  First Monday back in action. I'd say 21.6 mile...     NaN
# 52539   ddlovato  Crime shows, buddy, snuggles = the perfect Sun...     NaN
# 52540   ddlovato                          ❄️ http://t.co/sHCFdPpGPa     NaN
# 52541   ddlovato                      ❤️❄️✈️ http://t.co/ixmB5lv17Z     NaN
#
#               date_time            id language  latitude  longitude  \
# 0      12/01/2017 19:52  8.196330e+17       en       NaN        NaN
# 1      11/01/2017 08:38  8.191010e+17       en       NaN        NaN
# 2      11/01/2017 02:52  8.190140e+17       en       NaN        NaN
# 3      11/01/2017 02:44  8.190120e+17       en       NaN        NaN
# 4      10/01/2017 05:22  8.186890e+17       en       NaN        NaN
# ...                 ...           ...      ...       ...        ...
# 52537  06/01/2015 23:10  5.526030e+17       en       NaN        NaN
# 52538  06/01/2015 02:17  5.522880e+17       en       NaN        NaN
# 52539  05/01/2015 03:42  5.519470e+17       en       NaN        NaN
# 52540  05/01/2015 00:06  5.518920e+17      und       NaN        NaN
# 52541  05/01/2015 00:02  5.518910e+17      und       NaN        NaN
#
#        number_of_likes  number_of_shares
# 0                 7900              3472
# 1                 3689              1380
# 2                10341              2387
# 3                10774              2458
# 4                17620              4655
# ...                ...               ...
# 52537            32799             23796
# 52538            21709             12511
# 52539            25269             15583
# 52540            15985             10456
# 52541            16193             10822
#
# [52542 rows x 10 columns]

# %%
unique_people = tweets_df['author'].unique()
print(unique_people)
NUM_CLASSES = len(unique_people)

# assign each person a number
id_to_person = {i: unique_people[i] for i in range(len(unique_people))}
person_to_id = {v:k for k,v in id_to_person.items()}

# create a column of author ids
tweets_df['author_id'] = tweets_df['author'].apply(lambda x: person_to_id[x])
# Out:
# ['katyperry' 'justinbieber' 'taylorswift13' 'BarackObama' 'rihanna'
#  'YouTube' 'ladygaga' 'TheEllenShow' 'Twitter' 'jtimberlake'
#  'KimKardashian' 'britneyspears' 'Cristiano' 'selenagomez' 'cnnbrk'
#  'jimmyfallon' 'ArianaGrande' 'shakira' 'instagram' 'ddlovato']

# %%
tweets_df
# Out:
#           author                                            content country  \
# 0      katyperry  Is history repeating itself...?#DONTNORMALIZEH...     NaN
# 1      katyperry  @barackobama Thank you for your incredible gra...     NaN
# 2      katyperry                Life goals. https://t.co/XIn1qKMKQl     NaN
# 3      katyperry            Me right now 🙏🏻 https://t.co/gW55C1wrwd     NaN
# 4      katyperry  SISTERS ARE DOIN' IT FOR THEMSELVES! 🙌🏻💪🏻❤️ ht...     NaN
# ...          ...                                                ...     ...
# 52537   ddlovato               Life couldn't be better right now. 😊     NaN
# 52538   ddlovato  First Monday back in action. I'd say 21.6 mile...     NaN
# 52539   ddlovato  Crime shows, buddy, snuggles = the perfect Sun...     NaN
# 52540   ddlovato                          ❄️ http://t.co/sHCFdPpGPa     NaN
# 52541   ddlovato                      ❤️❄️✈️ http://t.co/ixmB5lv17Z     NaN
#
#               date_time            id language  latitude  longitude  \
# 0      12/01/2017 19:52  8.196330e+17       en       NaN        NaN
# 1      11/01/2017 08:38  8.191010e+17       en       NaN        NaN
# 2      11/01/2017 02:52  8.190140e+17       en       NaN        NaN
# 3      11/01/2017 02:44  8.190120e+17       en       NaN        NaN
# 4      10/01/2017 05:22  8.186890e+17       en       NaN        NaN
# ...                 ...           ...      ...       ...        ...
# 52537  06/01/2015 23:10  5.526030e+17       en       NaN        NaN
# 52538  06/01/2015 02:17  5.522880e+17       en       NaN        NaN
# 52539  05/01/2015 03:42  5.519470e+17       en       NaN        NaN
# 52540  05/01/2015 00:06  5.518920e+17      und       NaN        NaN
# 52541  05/01/2015 00:02  5.518910e+17      und       NaN        NaN
#
#        number_of_likes  number_of_shares  author_id
# 0                 7900              3472          0
# 1                 3689              1380          0
# 2                10341              2387          0
# 3                10774              2458          0
# 4                17620              4655          0
# ...                ...               ...        ...
# 52537            32799             23796         19
# 52538            21709             12511         19
# 52539            25269             15583         19
# 52540            15985             10456         19
# 52541            16193             10822         19
#
# [52542 rows x 11 columns]

# %%
class TweetDataset(Dataset):
    def __init__(self, df):
        print('making tokenizer...')
        self.tokenizer = AutoTokenizer.from_pretrained("vinai/bertweet-base", use_fast=False)
        print('making bert...')
        self.bertweet = AutoModel.from_pretrained("vinai/bertweet-base")
        
        print('tokenizing inputs...')
        self.inputs = self.tokenizer(list(df['content']), return_tensors="pt", padding=True, truncation=True)
        
        # Run BERT forward pass to get embeddings
        print('running BERT to get embeddings...')
        with torch.no_grad():
            features = self.bertweet(self.inputs.input_ids)
        
        self.embeddings = features.pooler_output
        self.labels = torch.tensor(df['author_id'].values).long()

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        
        x = self.embeddings[idx]
        y = self.labels[idx]
        
        return x, y

# %%
# shuffle the df
np.random.seed(7)
df_full = tweets_df.sample(frac=1.0)

# only do 1000/1000 for the sake of time
n_train = 1000
n_test = 1000

df_train = df_full[:n_train]
df_test = df_full[n_train:n_train+n_test]

ds_train = TweetDataset(df_train)
ds_test = TweetDataset(df_test)
# Out:
# making tokenizer...
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# making bert...
# Some weights of the model checkpoint at vinai/bertweet-base were not used when initializing RobertaModel: ['lm_head.decoder.bias', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizing inputs...
# running BERT to get embeddings...
# making tokenizer...
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# making bert...
# Some weights of the model checkpoint at vinai/bertweet-base were not used when initializing RobertaModel: ['lm_head.decoder.bias', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizing inputs...
# running BERT to get embeddings...

# %%
torch.manual_seed(7)

mlp = torch.nn.Sequential(
    torch.nn.Linear(768, 100),
    torch.nn.ReLU(),
    torch.nn.Linear(100, 100),
    torch.nn.ReLU(),
    torch.nn.Linear(100, NUM_CLASSES),
    torch.nn.Softmax(dim=1)
)

# %%
optimizer = torch.optim.Adam(mlp.parameters(), lr=1e-3)
loss_f = torch.nn.CrossEntropyLoss()

# %%
def get_accuracy(ds):
    num_correct = 0

    batch_start = 0
    batch_end = batch_start + batch_size
    print_counter = print_frequency
    while batch_start < len(ds):
        # Grab the batch from the dataset
        x, y = ds[batch_start:batch_end]

        # Forward pass
        with torch.no_grad():
            y_pred = mlp(x)

        # Gets the number of correct predictions
        num_correct += (torch.argmax(y_pred, dim=1) == y).numpy().sum()

        # Update batch parameters
        batch_start = batch_end
        batch_end = batch_start + batch_size
    
    return num_correct / len(ds)

# %%
# Randomly shuffle the indices
idxs = np.arange(len(ds_train))
np.random.shuffle(idxs)

# %%
mlp.train()
epochs = 100
batch_size = 64

# print every these number of batches
print_frequency = 5
print_counter = print_frequency

# Train loop
for epoch in range(epochs):
    batch_start = 0
    batch_end = batch_start + batch_size
    while batch_start < len(ds_train):
        # Grab the batch from the dataset
        idxs_batch = idxs[batch_start:batch_end]
        x, y = ds_train[idxs_batch]
               
        # Forward pass
        optimizer.zero_grad()
        y_pred = mlp(x)

        # Compute Loss
        ### TODO: your code here. Hint: how do we use loss_f? See Pytorch
        # documentation for examples.
        loss = None
        
        print_counter -= 1
        if print_counter <= 0:
            print_counter = print_frequency
            
            # Figure out which batch we are on
            batch_num = batch_start // batch_size
            print(f'Epoch {epoch}, Batch {batch_num}. Train loss: {loss.item()}')
        
        # Backward pass
        ### TODO: your code here. Hint: we need to do backpropogation and then
        # update parameters using the optimizer. Look up some examples of how to
        # to do this or go to Pytorch documentation.
        
        # Update batch parameters
        batch_start = batch_end
        batch_end = batch_start + batch_size
    
    print('\n----')
    
    train_acc = get_accuracy(ds_train)
    print(f'Train Acc on Epoch {epoch}:', train_acc)
    
    test_acc = get_accuracy(ds_test)
    print(f'Test Acc on Epoch {epoch}:', test_acc)
    
    print('----')
# Out:
# Epoch 0, Batch 4. Train loss: 2.9954159259796143
# Epoch 0, Batch 9. Train loss: 2.995896577835083
# Epoch 0, Batch 14. Train loss: 2.995283603668213
#
# ----
# Train Acc on Epoch 0: 0.058
# Test Acc on Epoch 0: 0.065
# ----
# Epoch 1, Batch 3. Train loss: 2.9940998554229736
# Epoch 1, Batch 8. Train loss: 2.993891954421997
# Epoch 1, Batch 13. Train loss: 2.994229793548584
#
# ----
# Train Acc on Epoch 1: 0.06
# Test Acc on Epoch 1: 0.079
# ----
# Epoch 2, Batch 2. Train loss: 2.992603063583374
# Epoch 2, Batch 7. Train loss: 2.9945790767669678
# Epoch 2, Batch 12. Train loss: 2.9930906295776367
#
# ----
# Train Acc on Epoch 2: 0.06
# Test Acc on Epoch 2: 0.078
# ----
# Epoch 3, Batch 1. Train loss: 2.996931791305542
# Epoch 3, Batch 6. Train loss: 2.9937074184417725
# Epoch 3, Batch 11. Train loss: 2.989109516143799
#
# ----
# Train Acc on Epoch 3: 0.06
# Test Acc on Epoch 3: 0.078
# ----
# Epoch 4, Batch 0. Train loss: 2.9990923404693604
# Epoch 4, Batch 5. Train loss: 2.995948553085327
# Epoch 4, Batch 10. Train loss: 2.985872507095337
# Epoch 4, Batch 15. Train loss: 2.9882073402404785
#
# ----
# Train Acc on Epoch 4: 0.066
# Test Acc on Epoch 4: 0.072
# ----
# Epoch 5, Batch 4. Train loss: 2.9834117889404297
# Epoch 5, Batch 9. Train loss: 3.001431703567505
# Epoch 5, Batch 14. Train loss: 2.9803428649902344
#
# ----
# Train Acc on Epoch 5: 0.071
# Test Acc on Epoch 5: 0.077
# ----
# Epoch 6, Batch 3. Train loss: 2.984849452972412
# Epoch 6, Batch 8. Train loss: 2.9866645336151123
# Epoch 6, Batch 13. Train loss: 2.9846482276916504
#
# ----
# Train Acc on Epoch 6: 0.102
# Test Acc on Epoch 6: 0.111
# ----
# Epoch 7, Batch 2. Train loss: 2.981443405151367
# Epoch 7, Batch 7. Train loss: 2.984246253967285
# Epoch 7, Batch 12. Train loss: 2.983698844909668
#
# ----
# Train Acc on Epoch 7: 0.08
# Test Acc on Epoch 7: 0.082
# ----
# Epoch 8, Batch 1. Train loss: 2.9929049015045166
# Epoch 8, Batch 6. Train loss: 2.991499900817871
# Epoch 8, Batch 11. Train loss: 2.986798048019409
#
# ----
# Train Acc on Epoch 8: 0.085
# Test Acc on Epoch 8: 0.079
# ----
# Epoch 9, Batch 0. Train loss: 3.0038979053497314
# Epoch 9, Batch 5. Train loss: 2.996880292892456
# Epoch 9, Batch 10. Train loss: 2.9794983863830566
# Epoch 9, Batch 15. Train loss: 2.968106508255005
#
# ----
# Train Acc on Epoch 9: 0.093
# Test Acc on Epoch 9: 0.094
# ----
# Epoch 10, Batch 4. Train loss: 2.9711897373199463
# Epoch 10, Batch 9. Train loss: 2.987020254135132
# Epoch 10, Batch 14. Train loss: 2.9646308422088623
#
# ----
# Train Acc on Epoch 10: 0.124
# Test Acc on Epoch 10: 0.115
# ----
# Epoch 11, Batch 3. Train loss: 2.983708143234253
# Epoch 11, Batch 8. Train loss: 2.967756509780884
# Epoch 11, Batch 13. Train loss: 2.9594781398773193
#
# ----
# Train Acc on Epoch 11: 0.127
# Test Acc on Epoch 11: 0.105
# ----
# Epoch 12, Batch 2. Train loss: 2.9665024280548096
# Epoch 12, Batch 7. Train loss: 2.961599349975586
# Epoch 12, Batch 12. Train loss: 2.9735426902770996
#
# ----
# Train Acc on Epoch 12: 0.12
# Test Acc on Epoch 12: 0.091
# ----
# Epoch 13, Batch 1. Train loss: 2.979893684387207
# Epoch 13, Batch 6. Train loss: 2.9890966415405273
# Epoch 13, Batch 11. Train loss: 2.9527318477630615
#
# ----
# Train Acc on Epoch 13: 0.115
# Test Acc on Epoch 13: 0.086
# ----
# Epoch 14, Batch 0. Train loss: 3.004030227661133
# Epoch 14, Batch 5. Train loss: 2.995896816253662
# Epoch 14, Batch 10. Train loss: 2.9790139198303223
# Epoch 14, Batch 15. Train loss: 2.9593725204467773
#
# ----
# Train Acc on Epoch 14: 0.114
# Test Acc on Epoch 14: 0.088
# ----
# Epoch 15, Batch 4. Train loss: 2.9628779888153076
# Epoch 15, Batch 9. Train loss: 2.9598937034606934
# Epoch 15, Batch 14. Train loss: 2.9364712238311768
#
# ----
# Train Acc on Epoch 15: 0.117
# Test Acc on Epoch 15: 0.087
# ----
# Epoch 16, Batch 3. Train loss: 2.9803075790405273
# Epoch 16, Batch 8. Train loss: 2.943915367126465
# Epoch 16, Batch 13. Train loss: 2.9352686405181885
#
# ----
# Train Acc on Epoch 16: 0.121
# Test Acc on Epoch 16: 0.088
# ----
# Epoch 17, Batch 2. Train loss: 2.9473061561584473
# Epoch 17, Batch 7. Train loss: 2.935487985610962
# Epoch 17, Batch 12. Train loss: 2.9577505588531494
#
# ----
# Train Acc on Epoch 17: 0.128
# Test Acc on Epoch 17: 0.092
# ----
# Epoch 18, Batch 1. Train loss: 2.9636311531066895
# Epoch 18, Batch 6. Train loss: 2.976785182952881
# Epoch 18, Batch 11. Train loss: 2.918689012527466
#
# ----
# Train Acc on Epoch 18: 0.132
# Test Acc on Epoch 18: 0.099
# ----
# Epoch 19, Batch 0. Train loss: 3.0029137134552
# Epoch 19, Batch 5. Train loss: 2.995063304901123
# Epoch 19, Batch 10. Train loss: 2.9706356525421143
# Epoch 19, Batch 15. Train loss: 2.944190502166748
#
# ----
# Train Acc on Epoch 19: 0.133
# Test Acc on Epoch 19: 0.101
# ----
# Epoch 20, Batch 4. Train loss: 2.950592279434204
# Epoch 20, Batch 9. Train loss: 2.942033529281616
# Epoch 20, Batch 14. Train loss: 2.9176557064056396
#
# ----
# Train Acc on Epoch 20: 0.133
# Test Acc on Epoch 20: 0.104
# ----
# Epoch 21, Batch 3. Train loss: 2.9700069427490234
# Epoch 21, Batch 8. Train loss: 2.930934429168701
# Epoch 21, Batch 13. Train loss: 2.9205551147460938
#
# ----
# Train Acc on Epoch 21: 0.137
# Test Acc on Epoch 21: 0.104
# ----
# Epoch 22, Batch 2. Train loss: 2.9262125492095947
# Epoch 22, Batch 7. Train loss: 2.918252944946289
# Epoch 22, Batch 12. Train loss: 2.9429640769958496
#
# ----
# Train Acc on Epoch 22: 0.137
# Test Acc on Epoch 22: 0.107
# ----
# Epoch 23, Batch 1. Train loss: 2.9457132816314697
# Epoch 23, Batch 6. Train loss: 2.9703519344329834
# Epoch 23, Batch 11. Train loss: 2.8931095600128174
#
# ----
# Train Acc on Epoch 23: 0.14
# Test Acc on Epoch 23: 0.112
# ----
# Epoch 24, Batch 0. Train loss: 2.994295358657837
# Epoch 24, Batch 5. Train loss: 2.990799903869629
# Epoch 24, Batch 10. Train loss: 2.963897466659546
# Epoch 24, Batch 15. Train loss: 2.9215738773345947
#
# ----
# Train Acc on Epoch 24: 0.141
# Test Acc on Epoch 24: 0.113
# ----
# Epoch 25, Batch 4. Train loss: 2.938711166381836
# Epoch 25, Batch 9. Train loss: 2.931474208831787
# Epoch 25, Batch 14. Train loss: 2.8994922637939453
#
# ----
# Train Acc on Epoch 25: 0.141
# Test Acc on Epoch 25: 0.114
# ----
# Epoch 26, Batch 3. Train loss: 2.9586174488067627
# Epoch 26, Batch 8. Train loss: 2.919708251953125
# Epoch 26, Batch 13. Train loss: 2.9124536514282227
#
# ----
# Train Acc on Epoch 26: 0.144
# Test Acc on Epoch 26: 0.113
# ----
# Epoch 27, Batch 2. Train loss: 2.9127492904663086
# Epoch 27, Batch 7. Train loss: 2.9071717262268066
# Epoch 27, Batch 12. Train loss: 2.9319159984588623
#
# ----
# Train Acc on Epoch 27: 0.143
# Test Acc on Epoch 27: 0.115
# ----
# Epoch 28, Batch 1. Train loss: 2.9343485832214355
# Epoch 28, Batch 6. Train loss: 2.963686227798462
# Epoch 28, Batch 11. Train loss: 2.8792481422424316
#
# ----
# Train Acc on Epoch 28: 0.15
# Test Acc on Epoch 28: 0.111
# ----
# Epoch 29, Batch 0. Train loss: 2.983254909515381
# Epoch 29, Batch 5. Train loss: 2.983261823654175
# Epoch 29, Batch 10. Train loss: 2.962538957595825
# Epoch 29, Batch 15. Train loss: 2.9057695865631104
#
# ----
# Train Acc on Epoch 29: 0.155
# Test Acc on Epoch 29: 0.11
# ----
# Epoch 30, Batch 4. Train loss: 2.934781312942505
# Epoch 30, Batch 9. Train loss: 2.9218573570251465
# Epoch 30, Batch 14. Train loss: 2.8882157802581787
#
# ----
# Train Acc on Epoch 30: 0.156
# Test Acc on Epoch 30: 0.113
# ----
# Epoch 31, Batch 3. Train loss: 2.9459469318389893
# Epoch 31, Batch 8. Train loss: 2.908200740814209
# Epoch 31, Batch 13. Train loss: 2.9051320552825928
#
# ----
# Train Acc on Epoch 31: 0.158
# Test Acc on Epoch 31: 0.111
# ----
# Epoch 32, Batch 2. Train loss: 2.9035298824310303
# Epoch 32, Batch 7. Train loss: 2.910503625869751
# Epoch 32, Batch 12. Train loss: 2.916797161102295
#
# ----
# Train Acc on Epoch 32: 0.155
# Test Acc on Epoch 32: 0.107
# ----
# Epoch 33, Batch 1. Train loss: 2.9307782649993896
# Epoch 33, Batch 6. Train loss: 2.963972806930542
# Epoch 33, Batch 11. Train loss: 2.869323968887329
#
# ----
# Train Acc on Epoch 33: 0.152
# Test Acc on Epoch 33: 0.102
# ----
# Epoch 34, Batch 0. Train loss: 2.9847419261932373
# Epoch 34, Batch 5. Train loss: 2.9806015491485596
# Epoch 34, Batch 10. Train loss: 2.973750114440918
# Epoch 34, Batch 15. Train loss: 2.909541130065918
#
# ----
# Train Acc on Epoch 34: 0.147
# Test Acc on Epoch 34: 0.094
# ----
# Epoch 35, Batch 4. Train loss: 2.9329938888549805
# Epoch 35, Batch 9. Train loss: 2.9331226348876953
# Epoch 35, Batch 14. Train loss: 2.8737223148345947
#
# ----
# Train Acc on Epoch 35: 0.151
# Test Acc on Epoch 35: 0.105
# ----
# Epoch 36, Batch 3. Train loss: 2.9409902095794678
# Epoch 36, Batch 8. Train loss: 2.900280714035034
# Epoch 36, Batch 13. Train loss: 2.9071457386016846
#
# ----
# Train Acc on Epoch 36: 0.157
# Test Acc on Epoch 36: 0.112
# ----
# Epoch 37, Batch 2. Train loss: 2.9049808979034424
# Epoch 37, Batch 7. Train loss: 2.8922536373138428
# Epoch 37, Batch 12. Train loss: 2.916461229324341
#
# ----
# Train Acc on Epoch 37: 0.157
# Test Acc on Epoch 37: 0.113
# ----
# Epoch 38, Batch 1. Train loss: 2.9160900115966797
# Epoch 38, Batch 6. Train loss: 2.956937313079834
# Epoch 38, Batch 11. Train loss: 2.8649752140045166
#
# ----
# Train Acc on Epoch 38: 0.153
# Test Acc on Epoch 38: 0.114
# ----
# Epoch 39, Batch 0. Train loss: 2.976438045501709
# Epoch 39, Batch 5. Train loss: 2.977034330368042
# Epoch 39, Batch 10. Train loss: 2.9655561447143555
# Epoch 39, Batch 15. Train loss: 2.8999714851379395
#
# ----
# Train Acc on Epoch 39: 0.158
# Test Acc on Epoch 39: 0.12
# ----
# Epoch 40, Batch 4. Train loss: 2.931910276412964
# Epoch 40, Batch 9. Train loss: 2.910217046737671
# Epoch 40, Batch 14. Train loss: 2.862657070159912
#
# ----
# Train Acc on Epoch 40: 0.158
# Test Acc on Epoch 40: 0.122
# ----
# Epoch 41, Batch 3. Train loss: 2.9255332946777344
# Epoch 41, Batch 8. Train loss: 2.8928229808807373
# Epoch 41, Batch 13. Train loss: 2.9020578861236572
#
# ----
# Train Acc on Epoch 41: 0.159
# Test Acc on Epoch 41: 0.122
# ----
# Epoch 42, Batch 2. Train loss: 2.889535903930664
# Epoch 42, Batch 7. Train loss: 2.883066177368164
# Epoch 42, Batch 12. Train loss: 2.912480592727661
#
# ----
# Train Acc on Epoch 42: 0.161
# Test Acc on Epoch 42: 0.122
# ----
# Epoch 43, Batch 1. Train loss: 2.906757116317749
# Epoch 43, Batch 6. Train loss: 2.955409288406372
# Epoch 43, Batch 11. Train loss: 2.8581628799438477
#
# ----
# Train Acc on Epoch 43: 0.16
# Test Acc on Epoch 43: 0.122
# ----
# Epoch 44, Batch 0. Train loss: 2.966921806335449
# Epoch 44, Batch 5. Train loss: 2.9680373668670654
# Epoch 44, Batch 10. Train loss: 2.9583866596221924
# Epoch 44, Batch 15. Train loss: 2.8999698162078857
#
# ----
# Train Acc on Epoch 44: 0.16
# Test Acc on Epoch 44: 0.122
# ----
# Epoch 45, Batch 4. Train loss: 2.934187889099121
# Epoch 45, Batch 9. Train loss: 2.9020192623138428
# Epoch 45, Batch 14. Train loss: 2.8611621856689453
#
# ----
# Train Acc on Epoch 45: 0.168
# Test Acc on Epoch 45: 0.126
# ----
# Epoch 46, Batch 3. Train loss: 2.9186599254608154
# Epoch 46, Batch 8. Train loss: 2.8666627407073975
# Epoch 46, Batch 13. Train loss: 2.8899130821228027
#
# ----
# Train Acc on Epoch 46: 0.166
# Test Acc on Epoch 46: 0.122
# ----
# Epoch 47, Batch 2. Train loss: 2.883718729019165
# Epoch 47, Batch 7. Train loss: 2.881117820739746
# Epoch 47, Batch 12. Train loss: 2.9232614040374756
#
# ----
# Train Acc on Epoch 47: 0.168
# Test Acc on Epoch 47: 0.127
# ----
# Epoch 48, Batch 1. Train loss: 2.903167724609375
# Epoch 48, Batch 6. Train loss: 2.957653760910034
# Epoch 48, Batch 11. Train loss: 2.8422064781188965
#
# ----
# Train Acc on Epoch 48: 0.17
# Test Acc on Epoch 48: 0.123
# ----
# Epoch 49, Batch 0. Train loss: 2.9500133991241455
# Epoch 49, Batch 5. Train loss: 2.954775333404541
# Epoch 49, Batch 10. Train loss: 2.9551401138305664
# Epoch 49, Batch 15. Train loss: 2.894014596939087
#
# ----
# Train Acc on Epoch 49: 0.172
# Test Acc on Epoch 49: 0.126
# ----
# Epoch 50, Batch 4. Train loss: 2.9254026412963867
# Epoch 50, Batch 9. Train loss: 2.8909926414489746
# Epoch 50, Batch 14. Train loss: 2.8514318466186523
#
# ----
# Train Acc on Epoch 50: 0.172
# Test Acc on Epoch 50: 0.126
# ----
# Epoch 51, Batch 3. Train loss: 2.9098215103149414
# Epoch 51, Batch 8. Train loss: 2.846815586090088
# Epoch 51, Batch 13. Train loss: 2.8798482418060303
#
# ----
# Train Acc on Epoch 51: 0.176
# Test Acc on Epoch 51: 0.127
# ----
# Epoch 52, Batch 2. Train loss: 2.8697242736816406
# Epoch 52, Batch 7. Train loss: 2.8696646690368652
# Epoch 52, Batch 12. Train loss: 2.9042601585388184
#
# ----
# Train Acc on Epoch 52: 0.178
# Test Acc on Epoch 52: 0.129
# ----
# Epoch 53, Batch 1. Train loss: 2.902731418609619
# Epoch 53, Batch 6. Train loss: 2.9573187828063965
# Epoch 53, Batch 11. Train loss: 2.829636573791504
#
# ----
# Train Acc on Epoch 53: 0.184
# Test Acc on Epoch 53: 0.135
# ----
# Epoch 54, Batch 0. Train loss: 2.936852216720581
# Epoch 54, Batch 5. Train loss: 2.9200451374053955
# Epoch 54, Batch 10. Train loss: 2.94966721534729
# Epoch 54, Batch 15. Train loss: 2.8816399574279785
#
# ----
# Train Acc on Epoch 54: 0.189
# Test Acc on Epoch 54: 0.138
# ----
# Epoch 55, Batch 4. Train loss: 2.917642116546631
# Epoch 55, Batch 9. Train loss: 2.886488199234009
# Epoch 55, Batch 14. Train loss: 2.8449349403381348
#
# ----
# Train Acc on Epoch 55: 0.193
# Test Acc on Epoch 55: 0.14
# ----
# Epoch 56, Batch 3. Train loss: 2.897045850753784
# Epoch 56, Batch 8. Train loss: 2.8382654190063477
# Epoch 56, Batch 13. Train loss: 2.867724657058716
#
# ----
# Train Acc on Epoch 56: 0.197
# Test Acc on Epoch 56: 0.144
# ----
# Epoch 57, Batch 2. Train loss: 2.867790699005127
# Epoch 57, Batch 7. Train loss: 2.863602876663208
# Epoch 57, Batch 12. Train loss: 2.8949310779571533
#
# ----
# Train Acc on Epoch 57: 0.198
# Test Acc on Epoch 57: 0.142
# ----
# Epoch 58, Batch 1. Train loss: 2.9075093269348145
# Epoch 58, Batch 6. Train loss: 2.9526093006134033
# Epoch 58, Batch 11. Train loss: 2.825220823287964
#
# ----
# Train Acc on Epoch 58: 0.197
# Test Acc on Epoch 58: 0.144
# ----
# Epoch 59, Batch 0. Train loss: 2.919370651245117
# Epoch 59, Batch 5. Train loss: 2.906127452850342
# Epoch 59, Batch 10. Train loss: 2.9464619159698486
# Epoch 59, Batch 15. Train loss: 2.860659122467041
#
# ----
# Train Acc on Epoch 59: 0.201
# Test Acc on Epoch 59: 0.146
# ----
# Epoch 60, Batch 4. Train loss: 2.9115045070648193
# Epoch 60, Batch 9. Train loss: 2.8809921741485596
# Epoch 60, Batch 14. Train loss: 2.843111515045166
#
# ----
# Train Acc on Epoch 60: 0.202
# Test Acc on Epoch 60: 0.141
# ----
# Epoch 61, Batch 3. Train loss: 2.887206792831421
# Epoch 61, Batch 8. Train loss: 2.8318896293640137
# Epoch 61, Batch 13. Train loss: 2.860316276550293
#
# ----
# Train Acc on Epoch 61: 0.203
# Test Acc on Epoch 61: 0.145
# ----
# Epoch 62, Batch 2. Train loss: 2.862591028213501
# Epoch 62, Batch 7. Train loss: 2.8651809692382812
# Epoch 62, Batch 12. Train loss: 2.8849031925201416
#
# ----
# Train Acc on Epoch 62: 0.206
# Test Acc on Epoch 62: 0.14
# ----
# Epoch 63, Batch 1. Train loss: 2.912583589553833
# Epoch 63, Batch 6. Train loss: 2.950355291366577
# Epoch 63, Batch 11. Train loss: 2.8223648071289062
#
# ----
# Train Acc on Epoch 63: 0.208
# Test Acc on Epoch 63: 0.139
# ----
# Epoch 64, Batch 0. Train loss: 2.9083523750305176
# Epoch 64, Batch 5. Train loss: 2.8926196098327637
# Epoch 64, Batch 10. Train loss: 2.9465460777282715
# Epoch 64, Batch 15. Train loss: 2.8493740558624268
#
# ----
# Train Acc on Epoch 64: 0.208
# Test Acc on Epoch 64: 0.139
# ----
# Epoch 65, Batch 4. Train loss: 2.911370038986206
# Epoch 65, Batch 9. Train loss: 2.87880802154541
# Epoch 65, Batch 14. Train loss: 2.8334927558898926
#
# ----
# Train Acc on Epoch 65: 0.211
# Test Acc on Epoch 65: 0.142
# ----
# Epoch 66, Batch 3. Train loss: 2.884131908416748
# Epoch 66, Batch 8. Train loss: 2.826401948928833
# Epoch 66, Batch 13. Train loss: 2.8591175079345703
#
# ----
# Train Acc on Epoch 66: 0.209
# Test Acc on Epoch 66: 0.152
# ----
# Epoch 67, Batch 2. Train loss: 2.8605797290802
# Epoch 67, Batch 7. Train loss: 2.851860284805298
# Epoch 67, Batch 12. Train loss: 2.8821568489074707
#
# ----
# Train Acc on Epoch 67: 0.208
# Test Acc on Epoch 67: 0.155
# ----
# Epoch 68, Batch 1. Train loss: 2.9045677185058594
# Epoch 68, Batch 6. Train loss: 2.947143316268921
# Epoch 68, Batch 11. Train loss: 2.816422939300537
#
# ----
# Train Acc on Epoch 68: 0.208
# Test Acc on Epoch 68: 0.154
# ----
# Epoch 69, Batch 0. Train loss: 2.894927978515625
# Epoch 69, Batch 5. Train loss: 2.873004674911499
# Epoch 69, Batch 10. Train loss: 2.9446065425872803
# Epoch 69, Batch 15. Train loss: 2.8590335845947266
#
# ----
# Train Acc on Epoch 69: 0.205
# Test Acc on Epoch 69: 0.15
# ----
# Epoch 70, Batch 4. Train loss: 2.9075539112091064
# Epoch 70, Batch 9. Train loss: 2.866442918777466
# Epoch 70, Batch 14. Train loss: 2.824613571166992
#
# ----
# Train Acc on Epoch 70: 0.204
# Test Acc on Epoch 70: 0.153
# ----
# Epoch 71, Batch 3. Train loss: 2.8803350925445557
# Epoch 71, Batch 8. Train loss: 2.821923017501831
# Epoch 71, Batch 13. Train loss: 2.8672940731048584
#
# ----
# Train Acc on Epoch 71: 0.204
# Test Acc on Epoch 71: 0.153
# ----
# Epoch 72, Batch 2. Train loss: 2.8448474407196045
# Epoch 72, Batch 7. Train loss: 2.841989278793335
# Epoch 72, Batch 12. Train loss: 2.892789125442505
#
# ----
# Train Acc on Epoch 72: 0.205
# Test Acc on Epoch 72: 0.155
# ----
# Epoch 73, Batch 1. Train loss: 2.890561103820801
# Epoch 73, Batch 6. Train loss: 2.94387149810791
# Epoch 73, Batch 11. Train loss: 2.8192989826202393
#
# ----
# Train Acc on Epoch 73: 0.208
# Test Acc on Epoch 73: 0.152
# ----
# Epoch 74, Batch 0. Train loss: 2.8868558406829834
# Epoch 74, Batch 5. Train loss: 2.875822067260742
# Epoch 74, Batch 10. Train loss: 2.936903715133667
# Epoch 74, Batch 15. Train loss: 2.8431661128997803
#
# ----
# Train Acc on Epoch 74: 0.212
# Test Acc on Epoch 74: 0.154
# ----
# Epoch 75, Batch 4. Train loss: 2.8988664150238037
# Epoch 75, Batch 9. Train loss: 2.863051652908325
# Epoch 75, Batch 14. Train loss: 2.8227014541625977
#
# ----
# Train Acc on Epoch 75: 0.217
# Test Acc on Epoch 75: 0.156
# ----
# Epoch 76, Batch 3. Train loss: 2.8754985332489014
# Epoch 76, Batch 8. Train loss: 2.815617084503174
# Epoch 76, Batch 13. Train loss: 2.866506338119507
#
# ----
# Train Acc on Epoch 76: 0.218
# Test Acc on Epoch 76: 0.156
# ----
# Epoch 77, Batch 2. Train loss: 2.8386809825897217
# Epoch 77, Batch 7. Train loss: 2.838611125946045
# Epoch 77, Batch 12. Train loss: 2.887225389480591
#
# ----
# Train Acc on Epoch 77: 0.22
# Test Acc on Epoch 77: 0.156
# ----
# Epoch 78, Batch 1. Train loss: 2.8890771865844727
# Epoch 78, Batch 6. Train loss: 2.941131591796875
# Epoch 78, Batch 11. Train loss: 2.817016124725342
#
# ----
# Train Acc on Epoch 78: 0.218
# Test Acc on Epoch 78: 0.154
# ----
# Epoch 79, Batch 0. Train loss: 2.870816469192505
# Epoch 79, Batch 5. Train loss: 2.8700389862060547
# Epoch 79, Batch 10. Train loss: 2.9312727451324463
# Epoch 79, Batch 15. Train loss: 2.8346047401428223
#
# ----
# Train Acc on Epoch 79: 0.222
# Test Acc on Epoch 79: 0.155
# ----
# Epoch 80, Batch 4. Train loss: 2.89699649810791
# Epoch 80, Batch 9. Train loss: 2.861377477645874
# Epoch 80, Batch 14. Train loss: 2.8216445446014404
#
# ----
# Train Acc on Epoch 80: 0.219
# Test Acc on Epoch 80: 0.154
# ----
# Epoch 81, Batch 3. Train loss: 2.8720998764038086
# Epoch 81, Batch 8. Train loss: 2.8142709732055664
# Epoch 81, Batch 13. Train loss: 2.8682096004486084
#
# ----
# Train Acc on Epoch 81: 0.222
# Test Acc on Epoch 81: 0.156
# ----
# Epoch 82, Batch 2. Train loss: 2.832494020462036
# Epoch 82, Batch 7. Train loss: 2.8390209674835205
# Epoch 82, Batch 12. Train loss: 2.8878657817840576
#
# ----
# Train Acc on Epoch 82: 0.224
# Test Acc on Epoch 82: 0.158
# ----
# Epoch 83, Batch 1. Train loss: 2.887488603591919
# Epoch 83, Batch 6. Train loss: 2.93912410736084
# Epoch 83, Batch 11. Train loss: 2.817141532897949
#
# ----
# Train Acc on Epoch 83: 0.222
# Test Acc on Epoch 83: 0.158
# ----
# Epoch 84, Batch 0. Train loss: 2.86238956451416
# Epoch 84, Batch 5. Train loss: 2.867737293243408
# Epoch 84, Batch 10. Train loss: 2.9266128540039062
# Epoch 84, Batch 15. Train loss: 2.825429677963257
#
# ----
# Train Acc on Epoch 84: 0.225
# Test Acc on Epoch 84: 0.159
# ----
# Epoch 85, Batch 4. Train loss: 2.895418643951416
# Epoch 85, Batch 9. Train loss: 2.861067056655884
# Epoch 85, Batch 14. Train loss: 2.821774959564209
#
# ----
# Train Acc on Epoch 85: 0.226
# Test Acc on Epoch 85: 0.158
# ----
# Epoch 86, Batch 3. Train loss: 2.8680319786071777
# Epoch 86, Batch 8. Train loss: 2.813079357147217
# Epoch 86, Batch 13. Train loss: 2.868690013885498
#
# ----
# Train Acc on Epoch 86: 0.224
# Test Acc on Epoch 86: 0.157
# ----
# Epoch 87, Batch 2. Train loss: 2.8280587196350098
# Epoch 87, Batch 7. Train loss: 2.8389761447906494
# Epoch 87, Batch 12. Train loss: 2.8864095211029053
#
# ----
# Train Acc on Epoch 87: 0.227
# Test Acc on Epoch 87: 0.158
# ----
# Epoch 88, Batch 1. Train loss: 2.8873684406280518
# Epoch 88, Batch 6. Train loss: 2.937385082244873
# Epoch 88, Batch 11. Train loss: 2.815021514892578
#
# ----
# Train Acc on Epoch 88: 0.225
# Test Acc on Epoch 88: 0.16
# ----
# Epoch 89, Batch 0. Train loss: 2.856942892074585
# Epoch 89, Batch 5. Train loss: 2.865513801574707
# Epoch 89, Batch 10. Train loss: 2.9226553440093994
# Epoch 89, Batch 15. Train loss: 2.8142693042755127
#
# ----
# Train Acc on Epoch 89: 0.225
# Test Acc on Epoch 89: 0.162
# ----
# Epoch 90, Batch 4. Train loss: 2.8932461738586426
# Epoch 90, Batch 9. Train loss: 2.8612751960754395
# Epoch 90, Batch 14. Train loss: 2.8237080574035645
#
# ----
# Train Acc on Epoch 90: 0.225
# Test Acc on Epoch 90: 0.161
# ----
# Epoch 91, Batch 3. Train loss: 2.861926794052124
# Epoch 91, Batch 8. Train loss: 2.8139641284942627
# Epoch 91, Batch 13. Train loss: 2.8655288219451904
#
# ----
# Train Acc on Epoch 91: 0.227
# Test Acc on Epoch 91: 0.158
# ----
# Epoch 92, Batch 2. Train loss: 2.826240062713623
# Epoch 92, Batch 7. Train loss: 2.8386452198028564
# Epoch 92, Batch 12. Train loss: 2.8825736045837402
#
# ----
# Train Acc on Epoch 92: 0.225
# Test Acc on Epoch 92: 0.156
# ----
# Epoch 93, Batch 1. Train loss: 2.887225866317749
# Epoch 93, Batch 6. Train loss: 2.9354920387268066
# Epoch 93, Batch 11. Train loss: 2.813591718673706
#
# ----
# Train Acc on Epoch 93: 0.226
# Test Acc on Epoch 93: 0.158
# ----
# Epoch 94, Batch 0. Train loss: 2.85137677192688
# Epoch 94, Batch 5. Train loss: 2.8632545471191406
# Epoch 94, Batch 10. Train loss: 2.9200546741485596
# Epoch 94, Batch 15. Train loss: 2.8054022789001465
#
# ----
# Train Acc on Epoch 94: 0.226
# Test Acc on Epoch 94: 0.158
# ----
# Epoch 95, Batch 4. Train loss: 2.8932371139526367
# Epoch 95, Batch 9. Train loss: 2.863525390625
# Epoch 95, Batch 14. Train loss: 2.818662643432617
#
# ----
# Train Acc on Epoch 95: 0.227
# Test Acc on Epoch 95: 0.158
# ----
# Epoch 96, Batch 3. Train loss: 2.8585386276245117
# Epoch 96, Batch 8. Train loss: 2.813096761703491
# Epoch 96, Batch 13. Train loss: 2.862980604171753
#
# ----
# Train Acc on Epoch 96: 0.226
# Test Acc on Epoch 96: 0.159
# ----
# Epoch 97, Batch 2. Train loss: 2.8248002529144287
# Epoch 97, Batch 7. Train loss: 2.8381102085113525
# Epoch 97, Batch 12. Train loss: 2.8759987354278564
#
# ----
# Train Acc on Epoch 97: 0.228
# Test Acc on Epoch 97: 0.156
# ----
# Epoch 98, Batch 1. Train loss: 2.8866679668426514
# Epoch 98, Batch 6. Train loss: 2.9325850009918213
# Epoch 98, Batch 11. Train loss: 2.8123462200164795
#
# ----
# Train Acc on Epoch 98: 0.229
# Test Acc on Epoch 98: 0.156
# ----
# Epoch 99, Batch 0. Train loss: 2.8480868339538574
# Epoch 99, Batch 5. Train loss: 2.8577446937561035
# Epoch 99, Batch 10. Train loss: 2.9205896854400635
# Epoch 99, Batch 15. Train loss: 2.7993311882019043
#
# ----
# Train Acc on Epoch 99: 0.23
# Test Acc on Epoch 99: 0.157
# ----
